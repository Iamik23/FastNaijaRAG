# %% [markdown]
# <a href="https://colab.research.google.com/github/Iamik23/FastNaijaRAG/blob/main/notebooks/day1_pytorch_blitz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
# Out:
# 2.11.0+cpu

# %% [markdown]
# import torch
# import numpy as np

# %%
import torch
import numpy as np

# %%
data=[[1,2],[3,4]]
x_data=torch.tensor(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1162/3662336143.py in <cell line: 0>()
#       1 data=[[1,2],[3,4]]
# ----> 2 x_data=torch.tensors(data)
#
# /usr/local/lib/python3.13/dist-packages/torch/__init__.py in __getattr__(name)
#    2879             return importlib.import_module(f".{name}", __name__)
#    2880
# -> 2881         raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#    2882
#    2883
#
# AttributeError: module 'torch' has no attribute 'tensors'

# %%
data=[[1,2],[3,4]]
x_data=torch.tensor(data)

# %%
np_array=np.array(data)
x_np=torch.from_numpy(np_array)

# %%
x_ones=torch.ones_like(x_data)
x_rand=torch.rand_like(x_data,dtype=torch.float)
